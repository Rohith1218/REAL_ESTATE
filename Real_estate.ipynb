# %%
##                                                    BOSTON REAL ESTATE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk

# %%
df = pd.read_csv("HousingData.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.shape
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
imputer.fit(df)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.53715e-01, 0.00000e+00, 9.69000e+00, 0.00000e+00, 5.38000e-01,
#        6.20850e+00, 7.68000e+01, 3.20745e+00, 5.00000e+00, 3.30000e+02,
#        1.90500e+01, 3.91440e+02, 1.14300e+01, 2.12000e+01])

# %%
x= imputer.transform(df)
df_tr = pd.DataFrame(x,columns=df.columns)
df_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.479140   10.768775   11.028893    0.067194    0.554695    6.284634
# std      8.570832   23.025124    6.704679    0.250605    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.083235    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      2.808720    0.000000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.845850    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df_tr.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#df = df.dropna(axis=0)

# %%
df_tr.shape
# Out:
# (506, 14)

# %%
df_tr.hist(bins=50,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3f4f01a490>,
# ...
#       dtype=object)

# %%
## TRAIN-TEST SPLITTING

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df_tr,test_size=0.2,random_state = 42)
print(f"train set: {len(train_set)}\ntest set: {len(test_set)}")
# Out:
# train set: 404
# test set: 102

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1 ,test_size=0.2,random_state = 42)
for train_index, test_index in split.split(df_tr,df_tr['CHAS']):
    strat_train_set = df_tr.iloc[train_index]
    strat_test_set = df_tr.iloc[test_index]

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# 0.0    377
# 1.0     27
# Name: CHAS, dtype: int64

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# 0.0    95
# 1.0     7
# Name: CHAS, dtype: int64

# %%
361/27
# Out:
# 13.37037037037037

# %%
91/7
# Out:
# 13.0

# %%
df_tr = strat_train_set.copy()

# %%
##                                      LOOKING FOR CORRELATIONS

# %%
corr_matrix = df_tr.corr()
corr_matrix['MEDV'].sort_values(ascending = False)
# Out:
# MEDV       1.000000
# RM         0.669448
# ZN         0.377910
# B          0.352618
# DIS        0.255649
# CHAS       0.180458
# RAD       -0.365016
# CRIM      -0.375934
# AGE       -0.402325
# NOX       -0.436721
# TAX       -0.455906
# PTRATIO   -0.463827
# INDUS     -0.486657
# LSTAT     -0.716792
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
atr = ["MEDV","RM","ZN","LSTAT","PTRATIO"]
scatter_matrix(df_tr[atr],figsize=(14,10),alpha=0.8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3f4e154690>,
# ...
#       dtype=object)

# %%
df_tr.plot(kind='scatter',x='RM',y='MEDV',alpha=0.8)

# %%
##                                            ATTRIBUTE COMBINATIONS
# look at 5,6,7 cells

# %%
df_tr = strat_train_set.drop("MEDV",axis=1)
df_labels = strat_train_set["MEDV"].copy()

# %%
##                                    CREATING PIPELINE

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler',StandardScaler()),
])

# %%
df_num_tr = my_pipeline.fit_transform(df_tr)
df_num_tr
# Out:
# array([[ 1.32422813, -0.45978766,  1.03161878, ...,  0.80227627,
#         -3.64591946,  1.63792076],
#        [-0.3589771 , -0.45978766, -0.19869262, ..., -0.04178522,
#          0.43702072, -0.34934119],
#        [-0.38887529, -0.45978766, -0.64730616, ..., -0.27624675,
#          0.33376984, -1.13121475],
#        ...,
#        [-0.14375657, -0.45978766,  1.03161878, ...,  0.80227627,
#          0.17910424,  0.07275721],
#        [-0.39674673,  1.0016235 , -1.35698578, ..., -0.04178522,
#          0.42090094, -0.83517929],
#        [ 0.85793058, -0.45978766,  1.03161878, ...,  0.80227627,
#          0.45482623,  1.82064121]])

# %%
##                                            selecting desired model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#model = LinearRegression()
#model = DecisionTreeRegressor()
model = RandomForestRegressor()
model.fit(df_num_tr,df_labels)
# Out:
# RandomForestRegressor()

# %%
some_data = df_tr.iloc[:5]
some_labels = df_labels.iloc[:5]

# %%
prepared_data = my_pipeline.transform(some_data)
model.predict(prepared_data)
# Out:
# array([ 8.649, 22.585, 27.288, 17.833, 16.175])

# %%
list(some_labels)
# Out:
# [8.3, 23.1, 26.6, 17.8, 14.1]

# %%
from sklearn.metrics import mean_squared_error
df_predictions = model.predict(df_num_tr)
mse = mean_squared_error(df_labels,df_predictions)
rmse = np.sqrt(mse)
rmse
# Out:
# 1.3229555551832042

# %%
## cross validation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, df_num_tr,df_labels,scoring='neg_mean_squared_error',cv=10)
rmse_scores = np.sqrt(-scores)
rmse_scores
# Out:
# array([5.24849029, 4.18968565, 2.97557307, 3.10601276, 6.60025469,
#        3.19787367, 2.96238718, 3.60152843, 2.86058891, 2.85130615])

# %%
def print_scores(scores):
  print(f"scores: {scores}")
  print(f"mean: {scores.mean()}")
  print(f"standard diviation: {scores.std()}")
print_scores(rmse_scores)
# Out:
# scores: [5.24849029 4.18968565 2.97557307 3.10601276 6.60025469 3.19787367
#  2.96238718 3.60152843 2.86058891 2.85130615]
# mean: 3.7593700804303793
# standard diviation: 1.1883707784287794

# %%
#linear regression
#mean: 5.1718567804059665                  
#standard diviation: 1.31773369178385

#dession tree regression
#mean: 5.653136017246856 
#standard diviation: 1.011929513967278

#random forest regressor
#mean: 3.7593700804303793
#standard diviation: 1.1883707784287794

# %%
## saving the model

from joblib import dump,load
dump(model, 'real_estate.joblib')
# Out:
# ['real_estate.joblib']

# %%
prepared_data[0]
# Out:
# array([ 1.32422813, -0.45978766,  1.03161878, -0.26761547,  1.04294482,
#        -0.54840649,  0.94221398, -0.87733702,  1.63620137,  1.51480276,
#         0.80227627, -3.64591946,  1.63792076])

# %%
## usage

from joblib import dump, load
import numpy as np
model = load('real_estate.joblib')
f = np.array([[ 1.32422813, -0.45978766,  1.03161878, -0.26761547,  1.04294482,
              -35.54840649,  0.94221398, -5.87733702,  1.63620137,  1.51480276,
               0.80227627, -3.64591946,  1.63792076]])
model.predict(f)
# Out:
# array([8.591])
